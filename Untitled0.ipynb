# %% [markdown]
# <a href="https://colab.research.google.com/github/Kratika-30/Python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("/content/PS06_Dataset_6 - Copy.csv")

df = pd.DataFrame(data)
print("Original data:")
print(df)

df['Total'] = np.sum(df,axis=1)
df['Mean'] = np.mean(df,axis=1)


print(df)


print("First 5 Rows:")
print(df.head())

print("Last 5 rows:")
print(df.tail())

print("\nDataset Info:")
print(df.info())

print("Shape:")
print(df.shape)

print("\nStatistical Summary:")
print(df.describe())

print("\nMaximum Values:")
print(df.max())

print("\nMinimum Values:")
print(df.min())

data.plot()
plt.xlabel("Index")
plt.ylabel("Values")
plt.legend()
plt.show()

avg = df[['A','B','C','D']].mean()
plt.bar(avg.index,avg.values)
plt.xlabel('Index')
plt.ylabel('Values')
plt.show()
# Out:
# Original data:
#      A   B   C   D
# 0   80  45  91  18
# 1   17  65   4  61
# 2   60  58  73  11
# 3   99  18  27  18
# 4    6  69  89  58
# 5   98  70  38  23
# 6   33  65  53  31
# 7   11  12  17  69
# 8   38  70  93  49
# 9   38  44  14  85
# 10   6  57  29  96
# 11   8  41  31  42
# 12  50  54  54  61
# 13  52  22  34  78
# 14  76   4  25  75
# 15  72  75  78  25
# 16  47   6  69  71
# 17  51  45  61  39
# 18  55  87  30  34
# 19  53  22  23  59
# 20  47  99  54  24
# 21  89  91  44  26
# 22  33  59  19  10
# 23  91  78  66  71
# 24  67  57  38  34
#      A   B   C   D  Total   Mean
# 0   80  45  91  18    234   93.6
# 1   17  65   4  61    147   58.8
# 2   60  58  73  11    202   80.8
# 3   99  18  27  18    162   64.8
# 4    6  69  89  58    222   88.8
# 5   98  70  38  23    229   91.6
# 6   33  65  53  31    182   72.8
# 7   11  12  17  69    109   43.6
# 8   38  70  93  49    250  100.0
# 9   38  44  14  85    181   72.4
# 10   6  57  29  96    188   75.2
# ...
